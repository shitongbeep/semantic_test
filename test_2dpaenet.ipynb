# %%
from dataloaders.pc_dataset import SemanticKITTI
import argparse
import yaml
from easydict import EasyDict
from PIL import Image
from torchvision.transforms import transforms
import numpy as np
from torch.utils.data import DataLoader

totensor = transforms.ToTensor()
topil = transforms.ToPILImage()

args = argparse.ArgumentParser()
args = args.parse_args(args=[])
with open('./config/semantic.yaml') as stream:
    config = yaml.safe_load(stream)
config.update(vars(args))
args = EasyDict(config)
dataset = SemanticKITTI(args=args)
dataloader = DataLoader(dataset, 1, False)
cur_data = next(iter(dataloader))

# img = np.squeeze(cur_data['velodyne_proj_img0'][0].data.cpu().numpy())
# img = (img * 256.0).astype('uint16')
# img_buffer = img.tobytes()
# imgsave = Image.new("I", img.T.shape)
# imgsave.frombytes(img_buffer, 'raw', "I;16")
# imgsave.save('./saveimg.png')
# imgsave.show()

# cur_data['velodyne_proj_img0'][cur_data['denser_coordinate'][:,1], cur_data['denser_coordinate'][:,0]] = 500.
show_img = topil(cur_data['velodyne_proj_img'][0])
show_img.show()
# Out:
# <PIL.Image.Image image mode=L size=4864x352>

# %%
import torch.nn.functional as F
import torch

img_torch = cur_data['velodyne_proj_img0']
H = img_torch.shape[2]
W = img_torch.shape[3]
img_unfold = F.unfold(img_torch, 2, stride=2)
_, index = img_unfold.topk(1, dim=1)
img_fold = torch.gather(img_unfold, dim=1, index=index).view(1, 1, H // 2, W // 2)
print(img_fold.shape)
show_pooling = topil(img_fold[0]/255.)
show_pooling.show()
# Out:
# torch.Size([1, 1, 176, 608])
# <PIL.Image.Image image mode=L size=608x176>

# %%
from depth_completion._2dpaenet import get_model as DepthCompletionModel

model = DepthCompletionModel(args).cuda()
model = model.load_from_checkpoint('./best_2dpaenet-v1.ckpt', args=args, strict=False).cuda()
with torch.no_grad():
    output_data = model(cur_data)
refine_img = output_data['all_dd_branch_output']
img = np.squeeze(refine_img.data.cpu().numpy())
img = (img).astype('uint16')
img_buffer = img.tobytes()
imgsave = Image.new("I", img.T.shape)
imgsave.frombytes(img_buffer, 'raw', "I;16")
imgsave.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 4
#       1 from depth_completion._2dpaenet import get_model as DepthCompletionModel
#       3 model = DepthCompletionModel(args).cuda()
# ----> 4 model = model.load_from_checkpoint('./best_2dpapenet.ckpt', args=args, strict=False).cuda()
#       5 with torch.no_grad():
#       6     output_data = model(cur_data)
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:136, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      56 @classmethod
#      57 def load_from_checkpoint(
#      58     cls,
#    (...)
#      63     **kwargs: Any,
#      64 ) -> Union["pl.LightningModule", "pl.LightningDataModule"]:
#      65     r"""
#      66     Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#      67     it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    (...)
#     134         y_hat = pretrained_model(x)
#     135     """
# --> 136     return _load_from_checkpoint(
#     137         cls,
#     138         checkpoint_path,
#     139         map_location,
#     140         hparams_file,
#     141         strict,
#     142         **kwargs,
#     143     )
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:157, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     155     map_location = cast(_MAP_LOCATION_TYPE, lambda storage, loc: storage)
#     156 with pl_legacy_patch():
# --> 157     checkpoint = pl_load(checkpoint_path, map_location=map_location)
#     159 if hparams_file is not None:
#     160     extension = str(hparams_file).split(".")[-1]
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/lightning_lite/utilities/cloud_io.py:47, in _load(path_or_url, map_location)
#      42     return torch.hub.load_state_dict_from_url(
#      43         str(path_or_url),
#      44         map_location=map_location,  # type: ignore[arg-type] # upstream annotation is not correct
#      45     )
#      46 fs = get_filesystem(path_or_url)
# ---> 47 with fs.open(path_or_url, "rb") as f:
#      48     return torch.load(f, map_location=map_location)
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/fsspec/spec.py:1094, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1092 else:
#    1093     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1094     f = self._open(
#    1095         path,
#    1096         mode=mode,
#    1097         block_size=block_size,
#    1098         autocommit=ac,
#    1099         cache_options=cache_options,
#    1100         **kwargs,
#    1101     )
#    1102     if compression is not None:
#    1103         from fsspec.compression import compr
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/fsspec/implementations/local.py:175, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     173 if self.auto_mkdir and "w" in mode:
#     174     self.makedirs(self._parent(path), exist_ok=True)
# --> 175 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/fsspec/implementations/local.py:273, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     271 self.compression = get_compression(path, compression)
#     272 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 273 self._open()
#
# File ~/miniconda3/envs/penet/lib/python3.8/site-packages/fsspec/implementations/local.py:278, in LocalFileOpener._open(self)
#     276 if self.f is None or self.f.closed:
#     277     if self.autocommit or "w" not in self.mode:
# --> 278         self.f = open(self.path, mode=self.mode)
#     279         if self.compression:
#     280             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/autodl-nas/semantic_test/./best_2dpapenet.ckpt'

# %%
unfold_op = torch.nn.Unfold(2, stride=2)
fold_op = torch.nn.Fold((refine_img.shape[-2], refine_img.shape[-1]), 2, stride=2)
refine_edge = unfold_op(refine_img).permute(0, 2, 1).contiguous()
top_num, _ = refine_edge.topk(1, dim=2, largest=True)
bottom_num, _ = refine_edge.topk(1, dim=2, largest=False)
mask = (top_num - bottom_num > 0.2).squeeze(-1)
refine_edge[mask] = 0
refine_img = fold_op(refine_edge.permute(0,2,1).contiguous())
output_data['all_dd_branch_output'] = refine_img
print(mask.shape)
print(refine_edge[mask].shape)

img = np.squeeze(refine_img.data.cpu().numpy())
img = (img).astype('uint16')
img_buffer = img.tobytes()
imgsave = Image.new("I", img.T.shape)
imgsave.frombytes(img_buffer, 'raw', "I;16")
imgsave.show()
# Out:
# torch.Size([1, 428032])
# torch.Size([198136, 4])
# <PIL.Image.Image image mode=L size=4864x352>

# %%
print(output_data.keys())
# Out:
# dict_keys(['raw_data', 'K', 'T_velo2img', 'T_4img', 'T_xyz', 'position', 'proj_points', 'sparse_proj_points', 'proj_distance', 'denser_coordinate', 'denser_coordinate_lines', 'velodyne_proj_img', 'velodyne_proj_img0', 'velodyne_proj_img1', 'velodyne_proj_img2', 'velodyne_proj_img3', 'feature_s1_img0', 'feature_s2_img0', 'feature_s3_img0', 'dd_branch_output_img0', 'feature_s1_img1', 'feature_s2_img1', 'feature_s3_img1', 'dd_branch_output_img1', 'feature_s1_img2', 'feature_s2_img2', 'feature_s3_img2', 'dd_branch_output_img2', 'feature_s1_img3', 'feature_s2_img3', 'feature_s3_img3', 'dd_branch_output_img3', 'all_dd_branch_output'])

# %%
sparse_img = cur_data['velodyne_proj_img'][0].permute(1, 2, 0).cpu().numpy().squeeze()
max_dist = sparse_img.max()
print(sparse_img.shape)
dense_img = cur_data['all_dd_branch_output'][0].permute(1, 2, 0).cpu().detach().numpy().squeeze()
print(dense_img.shape)
dense_coord = output_data['denser_coordinate'][0]
print(dense_coord.shape)
sparse_img[dense_coord[:, 1], dense_coord[:, 0]] = dense_img[dense_coord[:, 1], dense_coord[:, 0]]
sparse_img[dense_coord[:, 1], dense_coord[:, 0] + W] = dense_img[dense_coord[:, 1], dense_coord[:, 0] + W]
sparse_img[dense_coord[:, 1], dense_coord[:, 0] + 2 * W] = dense_img[dense_coord[:, 1], dense_coord[:, 0] + 2 * W]
sparse_img[dense_coord[:, 1], dense_coord[:, 0] + 3 * W] = dense_img[dense_coord[:, 1], dense_coord[:, 0] + 3 * W]

sparse_img[sparse_img > max_dist] = 0
sparse_img = (sparse_img - sparse_img.min()) / (sparse_img.max() - sparse_img.min()) * 255.
denser_img = Image.fromarray(sparse_img)
denser_img.show()
# Out:
# (352, 4864)
# (352, 4864)
# torch.Size([21691, 2])
# <PIL.Image.Image image mode=L size=4864x352>

# %%
denser_coordinate_lines = [lines.cpu().numpy().squeeze() for lines in output_data['denser_coordinate_lines']]
sparse_proj_points = [points.cpu().numpy().squeeze() for points in output_data['sparse_proj_points']]
K = output_data['K'].cpu().numpy().squeeze()
T_velo2img = output_data['T_velo2img'].cpu().numpy().squeeze()[:3, :3]
T_4img = output_data['T_4img'].cpu().numpy().squeeze()[:3, :3]
K_inv = K[:3, :3]
K_inv = np.linalg.inv(K_inv)
T_velo2img_inv = np.linalg.inv(T_velo2img)
T_4img_inv = np.linalg.inv(T_4img)

print(len(denser_coordinate_lines))
for i in range(len(denser_coordinate_lines)):
    insert_coords = denser_coordinate_lines[i]
    cat_ones = np.ones((insert_coords.shape[0], 1))
    insert_proj_points = np.concatenate([insert_coords, cat_ones], axis=1)
    # -pi/4  pi/4
    z_axis = dense_img[insert_coords[:, 1], insert_coords[:, 0]]
    z_axis = np.expand_dims(z_axis, -1)
    insert_proj_points0 = (K_inv @ insert_proj_points.T).T * z_axis
    insert_proj_points0 = (T_velo2img_inv @ insert_proj_points0.T).T
    mask = insert_proj_points0[0:1, ...] > 0
    insert_proj_points0[mask]
    # pi/4  3pi/4
    z_axis = dense_img[insert_coords[:, 1], insert_coords[:, 0] + W]
    z_axis = np.expand_dims(z_axis, -1)
    insert_proj_points1 = (K_inv @ insert_proj_points.T).T * z_axis
    insert_proj_points1 = (T_4img_inv @ T_velo2img_inv @ insert_proj_points1.T).T
    # 3pi/4  -3pi/4
    z_axis = dense_img[insert_coords[:, 1], insert_coords[:, 0] + 2 * W]
    z_axis = np.expand_dims(z_axis, -1)
    insert_proj_points2 = (K_inv @ insert_proj_points.T).T * z_axis
    insert_proj_points2 = (T_4img_inv @ T_4img_inv @ T_velo2img_inv @ insert_proj_points2.T).T
    # -3pi/4  -pi/4
    z_axis = dense_img[insert_coords[:, 1], insert_coords[:, 0] + 3 * W]
    z_axis = np.expand_dims(z_axis, -1)
    insert_proj_points3 = (K_inv @ insert_proj_points.T).T * z_axis
    insert_proj_points3 = (T_4img_inv @ T_4img_inv @ T_4img_inv @ T_velo2img_inv @ insert_proj_points3.T).T
    insert_proj_points = [insert_proj_points0, insert_proj_points1, insert_proj_points2, insert_proj_points3]
    insert_proj_points = np.concatenate(insert_proj_points, axis=0)
    # print(insert_proj_points.shape)
    # print(insert_proj_points3.shape)
    sparse_proj_points.insert(3 * i, insert_proj_points)
    # print(insert_proj_points.shape)

sparse_proj_points = np.concatenate(sparse_proj_points, axis=0)
print(len(sparse_proj_points))
# Out:
# 48
# 210568

# %%
cat_ones = np.ones((sparse_proj_points.shape[0], 1))
sparse_proj_points = np.concatenate([sparse_proj_points, cat_ones], axis=1).astype(np.float32)
T_xyz = output_data['T_xyz']
T_xyz_inv = np.linalg.inv(T_xyz)
sparse_proj_points = (T_xyz_inv @ sparse_proj_points.T).T.astype(np.float32)
sparse_proj_points.tofile('./bin/denserpc.bin')
print(K)
# Out:
# [[608.   0. 608.   0.]
#  [  0. 608. 176.   0.]
#  [  0.   0.   1.   0.]]
